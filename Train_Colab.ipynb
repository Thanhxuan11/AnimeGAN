# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !chmod +x Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !./Miniconda3-py38_4.12.0-Linux-x86_64.sh -b -f -p /usr/local
# !conda update conda
# Out:
# --2024-09-25 09:05:37--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76120962 (73M) [application/x-sh]
# Saving to: ‘Miniconda3-py38_4.12.0-Linux-x86_64.sh’
#
# Miniconda3-py38_4.1 100%[===================>]  72.59M   255MB/s    in 0.3s
#
# 2024-09-25 09:05:37 (255 MB/s) - ‘Miniconda3-py38_4.12.0-Linux-x86_64.sh’ saved [76120962/76120962]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py38h27cfd23_1003
#     - ca-certificates==2022.3.29=h06a4308_1
#     - certifi==2021.10.8=py38h06a4308_2
#     - cffi==1.15.0=py38hd667e15_1
#     - charset-normalizer==2.0.4=pyhd3eb1b0_0
#     - colorama==0.4.4=pyhd3eb1b0_0
#     - conda-content-trust==0.1.1=pyhd3eb1b0_0
#     - conda-package-handling==1.8.1=py38h7f8727e_0
#     - conda==4.12.0=py38h06a4308_0
#     - cryptography==36.0.0=py38h9ce1e76_0
#     - idna==3.3=pyhd3eb1b0_0
#     - ld_impl_linux-64==2.35.1=h7274673_9
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.3.0=h5101ec6_17
#     - libgomp==9.3.0=h5101ec6_17
#     - libstdcxx-ng==9.3.0=hd4cf53a_17
#     - ncurses==6.3=h7f8727e_2
#     - openssl==1.1.1n=h7f8727e_0
#     - pip==21.2.4=py38h06a4308_0
#     - pycosat==0.6.3=py38h7b6447c_1
#     - pycparser==2.21=pyhd3eb1b0_0
#     - pyopenssl==22.0.0=pyhd3eb1b0_0
#     - pysocks==1.7.1=py38h06a4308_0
#     - python==3.8.13=h12debd9_0
#     - readline==8.1.2=h7f8727e_1
#     - requests==2.27.1=pyhd3eb1b0_0
#     - ruamel_yaml==0.15.100=py38h27cfd23_0
#     - setuptools==61.2.0=py38h06a4308_0
#     - six==1.16.0=pyhd3eb1b0_1
#     - sqlite==3.38.2=hc218d9a_0
#     - tk==8.6.11=h1ccaba5_0
#     - tqdm==4.63.0=pyhd3eb1b0_0
#     - urllib3==1.26.8=pyhd3eb1b0_0
#     - wheel==0.37.1=pyhd3eb1b0_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.2.5=h7b6447c_0
#     - zlib==1.2.12=h7f8727e_1
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-4.5-1_gnu
#   brotlipy           pkgs/main/linux-64::brotlipy-0.7.0-py38h27cfd23_1003
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2022.3.29-h06a4308_1
#   certifi            pkgs/main/linux-64::certifi-2021.10.8-py38h06a4308_2
#   cffi               pkgs/main/linux-64::cffi-1.15.0-py38hd667e15_1
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   colorama           pkgs/main/noarch::colorama-0.4.4-pyhd3eb1b0_0
#   conda              pkgs/main/linux-64::conda-4.12.0-py38h06a4308_0
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust-0.1.1-pyhd3eb1b0_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.8.1-py38h7f8727e_0
#   cryptography       pkgs/main/linux-64::cryptography-36.0.0-py38h9ce1e76_0
#   idna               pkgs/main/noarch::idna-3.3-pyhd3eb1b0_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.35.1-h7274673_9
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.3.0-h5101ec6_17
#   libgomp            pkgs/main/linux-64::libgomp-9.3.0-h5101ec6_17
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.3.0-hd4cf53a_17
#   ncurses            pkgs/main/linux-64::ncurses-6.3-h7f8727e_2
#   openssl            pkgs/main/linux-64::openssl-1.1.1n-h7f8727e_0
#   pip                pkgs/main/linux-64::pip-21.2.4-py38h06a4308_0
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py38h7b6447c_1
#   pycparser          pkgs/main/noarch::pycparser-2.21-pyhd3eb1b0_0
#   pyopenssl          pkgs/main/noarch::pyopenssl-22.0.0-pyhd3eb1b0_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py38h06a4308_0
#   python             pkgs/main/linux-64::python-3.8.13-h12debd9_0
#   readline           pkgs/main/linux-64::readline-8.1.2-h7f8727e_1
#   requests           pkgs/main/noarch::requests-2.27.1-pyhd3eb1b0_0
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.100-py38h27cfd23_0
#   setuptools         pkgs/main/linux-64::setuptools-61.2.0-py38h06a4308_0
#   six                pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_1
#   sqlite             pkgs/main/linux-64::sqlite-3.38.2-hc218d9a_0
#   tk                 pkgs/main/linux-64::tk-8.6.11-h1ccaba5_0
#   tqdm               pkgs/main/noarch::tqdm-4.63.0-pyhd3eb1b0_0
#   urllib3            pkgs/main/noarch::urllib3-1.26.8-pyhd3eb1b0_0
#   wheel              pkgs/main/noarch::wheel-0.37.1-pyhd3eb1b0_0
#   xz                 pkgs/main/linux-64::xz-5.2.5-h7b6447c_0
#   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
#   zlib               pkgs/main/linux-64::zlib-1.2.12-h7f8727e_1
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     brotli-python-1.0.9        |   py38h6a678d5_8         356 KB
#     ca-certificates-2024.7.2   |       h06a4308_0         127 KB
#     certifi-2024.8.30          |   py38h06a4308_0         162 KB
#     cffi-1.17.1                |   py38h1fdaa30_0         253 KB
#     charset-normalizer-3.3.2   |     pyhd3eb1b0_0          44 KB
#     conda-package-handling-2.3.0|   py38h06a4308_0         269 KB
#     conda-package-streaming-0.10.0|   py38h06a4308_0          27 KB
#     cryptography-43.0.0        |   py38hdda0065_0         2.2 MB
#     idna-3.7                   |   py38h06a4308_0         113 KB
#     ld_impl_linux-64-2.38      |       h1181459_1         654 KB
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
#     libgomp-11.2.0             |       h1234567_1         474 KB
#     libstdcxx-ng-11.2.0        |       h1234567_1         4.7 MB
#     lz4-c-1.9.4                |       h6a678d5_1         156 KB
#     ncurses-6.4                |       h6a678d5_0         914 KB
#     openssl-3.0.15             |       h5eee18b_0         5.2 MB
#     pip-24.2                   |   py38h06a4308_0         2.2 MB
#     pycosat-0.6.6              |   py38h5eee18b_1          93 KB
#     pyopenssl-24.2.1           |   py38h06a4308_0          96 KB
#     python-3.8.19              |       h955ad1f_0        23.8 MB
#     readline-8.2               |       h5eee18b_0         357 KB
#     requests-2.32.3            |   py38h06a4308_0         100 KB
#     setuptools-75.1.0          |   py38h06a4308_0         1.7 MB
#     sqlite-3.45.3              |       h5eee18b_0         1.2 MB
#     tk-8.6.14                  |       h39e8969_0         3.4 MB
#     urllib3-2.2.2              |   py38h06a4308_0         177 KB
#     wheel-0.44.0               |   py38h06a4308_0         108 KB
#     xz-5.4.6                   |       h5eee18b_1         643 KB
#     zlib-1.2.13                |       h5eee18b_1         111 KB
#     zstandard-0.22.0           |   py38h2c38b39_0         427 KB
#     zstd-1.5.5                 |       hc292b87_2         643 KB
#     ------------------------------------------------------------
#                                            Total:        56.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli-python      pkgs/main/linux-64::brotli-python-1.0.9-py38h6a678d5_8
#   conda-package-str~ pkgs/main/linux-64::conda-package-streaming-0.10.0-py38h06a4308_0
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.4-h6a678d5_1
#   zstandard          pkgs/main/linux-64::zstandard-0.22.0-py38h2c38b39_0
#   zstd               pkgs/main/linux-64::zstd-1.5.5-hc292b87_2
#
# The following packages will be REMOVED:
#
#   brotlipy-0.7.0-py38h27cfd23_1003
#   colorama-0.4.4-pyhd3eb1b0_0
#   conda-content-trust-0.1.1-pyhd3eb1b0_0
#   six-1.16.0-pyhd3eb1b0_1
#   tqdm-4.63.0-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   _openmp_mutex                                   4.5-1_gnu --> 5.1-1_gnu
#   ca-certificates                      2022.3.29-h06a4308_1 --> 2024.7.2-h06a4308_0
#   certifi                          2021.10.8-py38h06a4308_2 --> 2024.8.30-py38h06a4308_0
#   cffi                                1.15.0-py38hd667e15_1 --> 1.17.1-py38h1fdaa30_0
#   charset-normalizer                     2.0.4-pyhd3eb1b0_0 --> 3.3.2-pyhd3eb1b0_0
#   conda-package-han~                   1.8.1-py38h7f8727e_0 --> 2.3.0-py38h06a4308_0
#   cryptography                        36.0.0-py38h9ce1e76_0 --> 43.0.0-py38hdda0065_0
#   idna               pkgs/main/noarch::idna-3.3-pyhd3eb1b0~ --> pkgs/main/linux-64::idna-3.7-py38h06a4308_0
#   ld_impl_linux-64                        2.35.1-h7274673_9 --> 2.38-h1181459_1
#   libffi                                     3.3-he6710b0_2 --> 3.4.4-h6a678d5_1
#   libgcc-ng                               9.3.0-h5101ec6_17 --> 11.2.0-h1234567_1
#   libgomp                                 9.3.0-h5101ec6_17 --> 11.2.0-h1234567_1
#   libstdcxx-ng                            9.3.0-hd4cf53a_17 --> 11.2.0-h1234567_1
#   ncurses                                    6.3-h7f8727e_2 --> 6.4-h6a678d5_0
#   openssl                                 1.1.1n-h7f8727e_0 --> 3.0.15-h5eee18b_0
#   pip                                 21.2.4-py38h06a4308_0 --> 24.2-py38h06a4308_0
#   pycosat                              0.6.3-py38h7b6447c_1 --> 0.6.6-py38h5eee18b_1
#   pyopenssl          pkgs/main/noarch::pyopenssl-22.0.0-py~ --> pkgs/main/linux-64::pyopenssl-24.2.1-py38h06a4308_0
#   python                                  3.8.13-h12debd9_0 --> 3.8.19-h955ad1f_0
#   readline                                 8.1.2-h7f8727e_1 --> 8.2-h5eee18b_0
#   requests           pkgs/main/noarch::requests-2.27.1-pyh~ --> pkgs/main/linux-64::requests-2.32.3-py38h06a4308_0
#   setuptools                          61.2.0-py38h06a4308_0 --> 75.1.0-py38h06a4308_0
#   sqlite                                  3.38.2-hc218d9a_0 --> 3.45.3-h5eee18b_0
#   tk                                      8.6.11-h1ccaba5_0 --> 8.6.14-h39e8969_0
#   urllib3            pkgs/main/noarch::urllib3-1.26.8-pyhd~ --> pkgs/main/linux-64::urllib3-2.2.2-py38h06a4308_0
#   wheel              pkgs/main/noarch::wheel-0.37.1-pyhd3e~ --> pkgs/main/linux-64::wheel-0.44.0-py38h06a4308_0
#   xz                                       5.2.5-h7b6447c_0 --> 5.4.6-h5eee18b_1
#   zlib                                    1.2.12-h7f8727e_1 --> 1.2.13-h5eee18b_1
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# zstd-1.5.5           | 643 KB    | : 100% 1.0/1 [00:00<00:00,  3.88it/s]
# libffi-3.4.4         | 141 KB    | : 100% 1.0/1 [00:00<00:00,  5.80it/s]
# sqlite-3.45.3        | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  5.99it/s]
# conda-package-handli | 269 KB    | : 100% 1.0/1 [00:00<00:00,  7.01it/s]
# conda-package-stream | 27 KB     | : 100% 1.0/1 [00:00<00:00,  7.33it/s]
# zstandard-0.22.0     | 427 KB    | : 100% 1.0/1 [00:00<00:00,  6.89it/s]
# python-3.8.19        | 23.8 MB   | : 100% 1.0/1 [00:00<00:00,  1.53it/s]
# requests-2.32.3      | 100 KB    | : 100% 1.0/1 [00:00<00:00,  6.80it/s]
# ncurses-6.4          | 914 KB    | : 100% 1.0/1 [00:00<00:00,  2.85it/s]
# idna-3.7             | 113 KB    | : 100% 1.0/1 [00:00<00:00,  6.78it/s]
# urllib3-2.2.2        | 177 KB    | : 100% 1.0/1 [00:00<00:00,  6.57it/s]
# brotli-python-1.0.9  | 356 KB    | : 100% 1.0/1 [00:00<00:00,  6.83it/s]
# pip-24.2             | 2.2 MB    | : 100% 1.0/1 [00:00<00:00,  3.78it/s]
# cffi-1.17.1          | 253 KB    | : 100% 1.0/1 [00:00<00:00,  6.85it/s]
# openssl-3.0.15       | 5.2 MB    | : 100% 1.0/1 [00:00<00:00,  4.19it/s]
# cryptography-43.0.0  | 2.2 MB    | : 100% 1.0/1 [00:00<00:00,  4.86it/s]
# libgcc-ng-11.2.0     | 5.3 MB    | : 100% 1.0/1 [00:00<00:00,  3.93it/s]
# libgomp-11.2.0       | 474 KB    | : 100% 1.0/1 [00:00<00:00,  6.80it/s]
# tk-8.6.14            | 3.4 MB    | : 100% 1.0/1 [00:00<00:00,  4.40it/s]
# certifi-2024.8.30    | 162 KB    | : 100% 1.0/1 [00:00<00:00,  6.90it/s]
# ca-certificates-2024 | 127 KB    | : 100% 1.0/1 [00:00<00:00,  7.60it/s]
# charset-normalizer-3 | 44 KB     | : 100% 1.0/1 [00:00<00:00,  7.60it/s]
# libstdcxx-ng-11.2.0  | 4.7 MB    | : 100% 1.0/1 [00:00<00:00,  4.23it/s]
# pycosat-0.6.6        | 93 KB     | : 100% 1.0/1 [00:00<00:00,  7.57it/s]
# _openmp_mutex-5.1    | 21 KB     | : 100% 1.0/1 [00:00<00:00,  7.18it/s]
# zlib-1.2.13          | 111 KB    | : 100% 1.0/1 [00:00<00:00,  7.24it/s]
# lz4-c-1.9.4          | 156 KB    | : 100% 1.0/1 [00:00<00:00,  7.45it/s]
# xz-5.4.6             | 643 KB    | : 100% 1.0/1 [00:00<00:00,  5.85it/s]
# readline-8.2         | 357 KB    | : 100% 1.0/1 [00:00<00:00,  7.04it/s]
# ld_impl_linux-64-2.3 | 654 KB    | : 100% 1.0/1 [00:00<00:00,  6.94it/s]
# setuptools-75.1.0    | 1.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.83it/s]
# pyopenssl-24.2.1     | 96 KB     | : 100% 1.0/1 [00:00<00:00,  7.43it/s]
# wheel-0.44.0         | 108 KB    | : 100% 1.0/1 [00:00<00:00,  6.95it/s]
# done
# done
# done

# %%
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages')

# %%
# !conda create -n myenv python=3.7
# Out:
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     pip-22.3.1                 |   py37h06a4308_0         2.7 MB
#     python-3.7.16              |       h7a1cb2a_0        44.8 MB
#     setuptools-65.6.3          |   py37h06a4308_0         1.1 MB
#     wheel-0.38.4               |   py37h06a4308_0          63 KB
#     ------------------------------------------------------------
#                                            Total:        52.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2024.7.2-h06a4308_0
#   certifi            pkgs/main/linux-64::certifi-2022.12.7-py37h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.38-h1181459_1
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1w-h7f8727e_0
#   pip                pkgs/main/linux-64::pip-22.3.1-py37h06a4308_0
#   python             pkgs/main/linux-64::python-3.7.16-h7a1cb2a_0
#   readline           pkgs/main/linux-64::readline-8.2-h5eee18b_0
#   setuptools         pkgs/main/linux-64::setuptools-65.6.3-py37h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.45.3-h5eee18b_0
#   tk                 pkgs/main/linux-64::tk-8.6.14-h39e8969_0
#   wheel              pkgs/main/linux-64::wheel-0.38.4-py37h06a4308_0
#   xz                 pkgs/main/linux-64::xz-5.4.6-h5eee18b_1
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_1
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# python-3.7.16        | 44.8 MB   | : 100% 1.0/1 [00:01<00:00,  1.11s/it]
# openssl-1.1.1w       | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  7.85it/s]
# setuptools-65.6.3    | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  6.08it/s]
# wheel-0.38.4         | 63 KB     | : 100% 1.0/1 [00:00<00:00, 23.20it/s]
# pip-22.3.1           | 2.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.27it/s]
# certifi-2022.12.7    | 150 KB    | : 100% 1.0/1 [00:00<00:00, 25.16it/s]
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate myenv
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# pip install tqdm
# pip install joblib==1.1.0
# pip install opencv-python==4.6.0.66
# pip install scikit-image==0.17.2
# pip install onnx==1.10.1
# pip install tensorflow-gpu==1.15.0
# pip install numpy==1.19.5
# pip install pillow==8.4.0
# pip install tf2onnx==1.10.1
# pip install coremltools==6.0
# Out:
# Collecting tqdm
#   Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 959.5 kB/s eta 0:00:00
# Installing collected packages: tqdm
# Successfully installed tqdm-4.66.5
# Collecting joblib==1.1.0
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: joblib
# Successfully installed joblib-1.1.0
# Collecting opencv-python==4.6.0.66
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 6.0 MB/s eta 0:00:00
# Collecting numpy>=1.14.5
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 51.0 MB/s eta 0:00:00
# Installing collected packages: numpy, opencv-python
# Successfully installed numpy-1.21.6 opencv-python-4.6.0.66
# Collecting scikit-image==0.17.2
#   Downloading scikit_image-0.17.2-cp37-cp37m-manylinux1_x86_64.whl (12.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 54.1 MB/s eta 0:00:00
# Collecting matplotlib!=3.0.0,>=2.0.0
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 57.6 MB/s eta 0:00:00
# Collecting networkx>=2.0
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 70.4 MB/s eta 0:00:00
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 19.2 MB/s eta 0:00:00
# Collecting scipy>=1.0.1
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 25.6 MB/s eta 0:00:00
# Collecting pillow!=7.1.0,!=7.1.1,>=4.3.0
#   Downloading Pillow-9.5.0-cp37-cp37m-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 87.3 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 75.1 MB/s eta 0:00:00
# Collecting imageio>=2.3.0
#   Downloading imageio-2.31.2-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.1 in /usr/local/envs/myenv/lib/python3.7/site-packages (from scikit-image==0.17.2) (1.21.6)
# Collecting packaging>=20.0
#   Downloading packaging-24.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 4.7 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 48.7 MB/s eta 0:00:00
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 12.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 51.7 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting python-dateutil>=2.7
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 20.1 MB/s eta 0:00:00
# Collecting typing-extensions
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting six>=1.5
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: typing-extensions, tifffile, six, scipy, PyWavelets, pyparsing, pillow, packaging, networkx, fonttools, cycler, python-dateutil, kiwisolver, imageio, matplotlib, scikit-image
# Successfully installed PyWavelets-1.3.0 cycler-0.11.0 fonttools-4.38.0 imageio-2.31.2 kiwisolver-1.4.5 matplotlib-3.5.3 networkx-2.6.3 packaging-24.0 pillow-9.5.0 pyparsing-3.1.4 python-dateutil-2.9.0.post0 scikit-image-0.17.2 scipy-1.7.3 six-1.16.0 tifffile-2021.11.2 typing-extensions-4.7.1
# Collecting onnx==1.10.1
#   Downloading onnx-1.10.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 55.0 MB/s eta 0:00:00
# Collecting protobuf
#   Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/envs/myenv/lib/python3.7/site-packages (from onnx==1.10.1) (1.21.6)
# Requirement already satisfied: six in /usr/local/envs/myenv/lib/python3.7/site-packages (from onnx==1.10.1) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/envs/myenv/lib/python3.7/site-packages (from onnx==1.10.1) (4.7.1)
# Installing collected packages: protobuf, onnx
# Successfully installed onnx-1.10.1 protobuf-4.24.4
# Collecting tensorflow-gpu==1.15.0
#   Downloading tensorflow_gpu-1.15.0-cp37-cp37m-manylinux2010_x86_64.whl (411.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.5/411.5 MB 2.1 MB/s eta 0:00:00
# Collecting absl-py>=0.7.0
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 11.5 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.0.5
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.10.0 in /usr/local/envs/myenv/lib/python3.7/site-packages (from tensorflow-gpu==1.15.0) (1.16.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/envs/myenv/lib/python3.7/site-packages (from tensorflow-gpu==1.15.0) (4.24.4)
# Collecting wrapt>=1.11.1
#   Downloading wrapt-1.16.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 7.8 MB/s eta 0:00:00
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.4/503.4 kB 38.6 MB/s eta 0:00:00
# Requirement already satisfied: wheel>=0.26 in /usr/local/envs/myenv/lib/python3.7/site-packages (from tensorflow-gpu==1.15.0) (0.38.4)
# Collecting astor>=0.6.0
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting google-pasta>=0.1.6
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.5 MB/s eta 0:00:00
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/envs/myenv/lib/python3.7/site-packages (from tensorflow-gpu==1.15.0) (1.21.6)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.7 MB/s eta 0:00:00
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting grpcio>=1.8.6
#   Downloading grpcio-1.62.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 4.5 MB/s eta 0:00:00
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 89.8 MB/s eta 0:00:00
# Collecting h5py
#   Downloading h5py-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 91.8 MB/s eta 0:00:00
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 20.9 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.4-py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/envs/myenv/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.0) (65.6.3)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/envs/myenv/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.0) (4.7.1)
# Collecting zipp>=0.5
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7537 sha256=90c63606ece8d7f329a3d19503b88f3e9f8a652fe8bdd209de661021fcd950f2
#   Stored in directory: /root/.cache/pip/wheels/cf/87/6f/3f34218ef184368cec9ee65bdfd65baf117811f0a0ce1263ff
# Successfully built gast
# Installing collected packages: tensorflow-estimator, zipp, wrapt, termcolor, opt-einsum, MarkupSafe, keras-preprocessing, h5py, grpcio, google-pasta, gast, astor, absl-py, werkzeug, keras-applications, importlib-metadata, markdown, tensorboard, tensorflow-gpu
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 astor-0.8.1 gast-0.2.2 google-pasta-0.2.0 grpcio-1.62.3 h5py-3.8.0 importlib-metadata-6.7.0 keras-applications-1.0.8 keras-preprocessing-1.1.2 markdown-3.4.4 opt-einsum-3.3.0 tensorboard-1.15.0 tensorflow-estimator-1.15.1 tensorflow-gpu-1.15.0 termcolor-2.3.0 werkzeug-2.2.3 wrapt-1.16.0 zipp-3.15.0
# Collecting numpy==1.19.5
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 62.9 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# Successfully installed numpy-1.19.5
# Collecting pillow==8.4.0
#   Downloading Pillow-8.4.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 10.5 MB/s eta 0:00:00
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.5.0
#     Uninstalling Pillow-9.5.0:
#       Successfully uninstalled Pillow-9.5.0
# Successfully installed pillow-8.4.0
# Collecting tf2onnx==1.10.1
#   Downloading tf2onnx-1.10.1-py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.2/440.2 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/envs/myenv/lib/python3.7/site-packages (from tf2onnx==1.10.1) (1.16.0)
# Collecting flatbuffers~=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/envs/myenv/lib/python3.7/site-packages (from tf2onnx==1.10.1) (1.19.5)
# Collecting requests
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: onnx>=1.4.1 in /usr/local/envs/myenv/lib/python3.7/site-packages (from tf2onnx==1.10.1) (1.10.1)
# Requirement already satisfied: protobuf in /usr/local/envs/myenv/lib/python3.7/site-packages (from onnx>=1.4.1->tf2onnx==1.10.1) (4.24.4)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/envs/myenv/lib/python3.7/site-packages (from onnx>=1.4.1->tf2onnx==1.10.1) (4.7.1)
# Collecting idna<4,>=2.5
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 7.0 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.8/136.8 kB 13.1 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.0.7-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/myenv/lib/python3.7/site-packages (from requests->tf2onnx==1.10.1) (2022.12.7)
# Installing collected packages: flatbuffers, urllib3, idna, charset-normalizer, requests, tf2onnx
# Successfully installed charset-normalizer-3.3.2 flatbuffers-1.12 idna-3.10 requests-2.31.0 tf2onnx-1.10.1 urllib3-2.0.7
# Collecting coremltools==6.0
#   Downloading coremltools-6.0-cp37-none-manylinux1_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.0 MB/s eta 0:00:00
# Collecting sympy
#   Downloading sympy-1.10.1-py3-none-any.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 54.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/envs/myenv/lib/python3.7/site-packages (from coremltools==6.0) (4.66.5)
# Requirement already satisfied: packaging in /usr/local/envs/myenv/lib/python3.7/site-packages (from coremltools==6.0) (24.0)
# Collecting protobuf<=3.20.1,>=3.1.0
#   Downloading protobuf-3.20.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 49.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/envs/myenv/lib/python3.7/site-packages (from coremltools==6.0) (1.19.5)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 33.7 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy, protobuf, coremltools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.24.4
#     Uninstalling protobuf-4.24.4:
#       Successfully uninstalled protobuf-4.24.4
# Successfully installed coremltools-6.0 mpmath-1.3.0 protobuf-3.20.1 sympy-1.10.1

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# pip list
# Out:
# Could not find conda environment: myenv
# You can list all discoverable environments with `conda info --envs`.
#
# Package                 Version
# ----------------------- ---------
# Brotli                  1.0.9
# certifi                 2024.8.30
# cffi                    1.17.1
# charset-normalizer      3.3.2
# conda                   4.12.0
# conda-package-handling  2.3.0
# conda_package_streaming 0.10.0
# cryptography            43.0.0
# idna                    3.7
# pip                     24.2
# pycosat                 0.6.6
# pycparser               2.21
# pyOpenSSL               24.2.1
# PySocks                 1.7.1
# requests                2.32.3
# ruamel-yaml-conda       0.15.100
# setuptools              75.1.0
# urllib3                 2.2.2
# wheel                   0.44.0
# zstandard               0.22.0

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# export PYTHONPATH=drive/MyDrive/AnimeGANv3-master
# python3 /content/drive/MyDrive/AnimeGANv3-master/train.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# npy file loaded -------  drive/MyDrive/AnimeGANv3-master/vgg19_weight/vgg19_no_fc.npy
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/train.py:73: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/train.py:73: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2024-09-25 09:09:15.106916: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2024-09-25 09:09:15.116702: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000185000 Hz
# 2024-09-25 09:09:15.120529: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x758e6e0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2024-09-25 09:09:15.120565: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2024-09-25 09:09:15.122081: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/envs/myenv/lib/python3.7/site-packages/cv2/../../lib64:
# 2024-09-25 09:09:15.122109: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-09-25 09:09:15.122137: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (b015b678b70b): /proc/driver/nvidia/version does not exist
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/AnimeGANv3.py:41: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
#
# ##### Information #####
# # dataset :  Tabe
# # max dataset number :  5064
# # batch_size :  8
# # epoch :  100
# # init_G_epoch :  5
# # training image size [H, W] :  [256, 256]
# # init_G_lr,g_lr,d_lr :  0.0002 0.0001 0.0001
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/AnimeGANv3.py:70: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /usr/local/envs/myenv/lib/python3.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/tools/ops.py:210: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/tools/ops.py:83: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/net/generator.py:21: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/tools/GuidedFilter.py:66: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/tools/GuidedFilter.py:68: The name tf.assert_greater is deprecated. Please use tf.compat.v1.assert_greater instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/tools/vgg19.py:128: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# build model finished: 0.107606s
# build model finished: 0.095678s
# build model finished: 0.094612s
# build model finished: 0.095489s
# build model finished: 0.096666s
# build model finished: 0.096375s
# build_multi model finished: 0.115539s
# build_multi model finished: 0.103299s
# build model finished: 0.100379s
# build model finished: 0.102893s
# build model finished: 0.097054s
# build model finished: 0.096539s
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/tools/tf_color_ops.py:310: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# build model finished: 0.100368s
# build model finished: 0.097218s
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/AnimeGANv3.py:136: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/AnimeGANv3.py:141: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/AnimeGANv3.py:141: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/AnimeGANv3.py:143: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/AnimeGANv3.py:152: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/AnimeGANv3.py:165: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# G:
# ---------
# Variables: name (type shape) [size]
# ---------
# generator/base/Conv/weights:0 (float32_ref 7x7x3x32) [4704, bytes: 18816]
# generator/base/Conv_1/weights:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/base/Conv_2/weights:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/base/Conv_3/weights:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/base/Conv_4/weights:0 (float32_ref 3x3x32x64) [18432, bytes: 73728]
# generator/base/Conv_5/weights:0 (float32_ref 1x1x64x64) [4096, bytes: 16384]
# generator/base/Conv_6/weights:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# generator/base/Conv_7/weights:0 (float32_ref 1x1x64x64) [4096, bytes: 16384]
# generator/base/Conv_8/weights:0 (float32_ref 3x3x64x128) [73728, bytes: 294912]
# generator/base/Conv_9/weights:0 (float32_ref 1x1x128x128) [16384, bytes: 65536]
# generator/base/Conv_10/weights:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# generator/base/Conv_11/weights:0 (float32_ref 1x1x128x128) [16384, bytes: 65536]
# generator/base/Conv_12/weights:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# generator/base/Conv_13/weights:0 (float32_ref 1x1x128x128) [16384, bytes: 65536]
# generator/support/External_attention/kernel:0 (float32_ref 1x128x128) [16384, bytes: 65536]
# generator/support/External_attention/Conv/weights:0 (float32_ref 1x1x128x128) [16384, bytes: 65536]
# generator/support/External_attention/Conv_1/weights:0 (float32_ref 1x1x128x128) [16384, bytes: 65536]
# generator/support/External_attention/Variable:0 (float32_ref 128) [128, bytes: 512]
# generator/support/External_attention/Variable_1:0 (float32_ref 128) [128, bytes: 512]
# generator/support/Conv/weights:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# generator/support/Conv_1/weights:0 (float32_ref 1x1x128x128) [16384, bytes: 65536]
# generator/support/Conv_2/weights:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# generator/support/Conv_3/weights:0 (float32_ref 1x1x128x128) [16384, bytes: 65536]
# generator/support/Conv_4/weights:0 (float32_ref 3x3x128x64) [73728, bytes: 294912]
# generator/support/Conv_5/weights:0 (float32_ref 1x1x64x64) [4096, bytes: 16384]
# generator/support/Conv_6/weights:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# generator/support/Conv_7/weights:0 (float32_ref 1x1x64x64) [4096, bytes: 16384]
# generator/support/Conv_8/weights:0 (float32_ref 3x3x64x32) [18432, bytes: 73728]
# generator/support/Conv_9/weights:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/support/Conv_10/weights:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/support/Conv_11/weights:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/support/Conv_12/weights:0 (float32_ref 7x7x32x3) [4704, bytes: 18816]
# generator/main/External_attention/kernel:0 (float32_ref 1x128x128) [16384, bytes: 65536]
# generator/main/External_attention/Conv/weights:0 (float32_ref 1x1x128x128) [16384, bytes: 65536]
# generator/main/External_attention/Conv_1/weights:0 (float32_ref 1x1x128x128) [16384, bytes: 65536]
# generator/main/External_attention/Variable:0 (float32_ref 128) [128, bytes: 512]
# generator/main/External_attention/Variable_1:0 (float32_ref 128) [128, bytes: 512]
# generator/main/Conv/weights:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# generator/main/Conv_1/weights:0 (float32_ref 1x1x128x128) [16384, bytes: 65536]
# generator/main/Conv_2/weights:0 (float32_ref 3x3x128x128) [147456, bytes: 589824]
# generator/main/Conv_3/weights:0 (float32_ref 1x1x128x128) [16384, bytes: 65536]
# generator/main/Conv_4/weights:0 (float32_ref 3x3x128x64) [73728, bytes: 294912]
# generator/main/Conv_5/weights:0 (float32_ref 1x1x64x64) [4096, bytes: 16384]
# generator/main/Conv_6/weights:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# generator/main/Conv_7/weights:0 (float32_ref 1x1x64x64) [4096, bytes: 16384]
# generator/main/Conv_8/weights:0 (float32_ref 3x3x64x32) [18432, bytes: 73728]
# generator/main/Conv_9/weights:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/main/Conv_10/weights:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/main/Conv_11/weights:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/main/Conv_12/weights:0 (float32_ref 7x7x32x3) [4704, bytes: 18816]
# generator_1/support/External_attention/Variable:0 (float32_ref 128) [128, bytes: 512]
# generator_1/support/External_attention/Variable_1:0 (float32_ref 128) [128, bytes: 512]
# generator_1/main/External_attention/Variable:0 (float32_ref 128) [128, bytes: 512]
# generator_1/main/External_attention/Variable_1:0 (float32_ref 128) [128, bytes: 512]
# Total size of variables: 1558304
# Total bytes of variables: 6233216
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/AnimeGANv3.py:170: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/AnimeGANv3.py:174: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/AnimeGANv3.py:178: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/tools/data_loader.py:66: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# WARNING:tensorflow:From /content/drive/MyDrive/AnimeGANv3-master/tools/data_loader.py:70: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
#  [*] Reading checkpoints...
#  [*] Success to read /content/drive/MyDrive/AnimeGANv3-master/checkpoint/AnimeGANv3_Tabe/AnimeGANv3.model-8
#  [*] Load SUCCESS
# Epoch:   9, Step:     0 /  500, time: 56.660s, ETA: 28386.64s, D_loss:0.178 ~ G_loss: 8.304 || G_support_loss: 5.707407, g_s_loss: 0.518980, con_loss: 0.162402, rs_loss: 0.222456, sty_loss: 3.923441, s22: 0.084917, s33: 1.449263, s44: 2.389261, color_loss: 0.880113, tv_loss: 0.000015 ~ D_support_loss: 0.129818 || G_main_loss: 2.596420, g_m_loss: 0.008496, p0_loss: 2.461068, p4_loss: 0.126828, tv_loss_m: 0.000028 ~ D_main_loss: 0.048449
# Epoch:   9, Step:     1 /  500, time: 14.907s, ETA: 7453.72s, D_loss:7.829 ~ G_loss: 33.245 || G_support_loss: 11.184670, g_s_loss: 1.493037, con_loss: 0.363638, rs_loss: 0.287444, sty_loss: 4.530468, s22: 0.101691, s33: 1.865807, s44: 2.562970, color_loss: 4.510079, tv_loss: 0.000005 ~ D_support_loss: 6.071102 || G_main_loss: 22.059990, g_m_loss: 0.013442, p0_loss: 21.668577, p4_loss: 0.377958, tv_loss_m: 0.000011 ~ D_main_loss: 1.758267
# Epoch:   9, Step:     2 /  500, time: 14.624s, ETA: 7297.44s, D_loss:0.354 ~ G_loss: 19.172 || G_support_loss: 8.505231, g_s_loss: 0.305040, con_loss: 0.262887, rs_loss: 0.242082, sty_loss: 4.368207, s22: 0.083404, s33: 1.555935, s44: 2.728868, color_loss: 3.327012, tv_loss: 0.000003 ~ D_support_loss: 0.279848 || G_main_loss: 10.667027, g_m_loss: 0.013197, p0_loss: 10.401735, p4_loss: 0.252086, tv_loss_m: 0.000008 ~ D_main_loss: 0.074303
